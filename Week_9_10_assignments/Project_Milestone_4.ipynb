# %%
# Import required libraries
import os
import requests
import json 
import pandas as pd

# %%
# Call the API
url='https://open.er-api.com/v6/latest/USD'
resp =requests.get('https://open.er-api.com/v6/latest/USD')

# %%
#Check the API response
print(resp.status_code)
# Out:
# 200

# %%
#Store the API response in a variable
data=resp.text

# %%
# Verify data
print(data)
# Out:
# {"result":"success","provider":"https://www.exchangerate-api.com","documentation":"https://www.exchangerate-api.com/docs/free","terms_of_use":"https://www.exchangerate-api.com/terms","time_last_update_unix":1653264151,"time_last_update_utc":"Mon, 23 May 2022 00:02:31 +0000","time_next_update_unix":1653350861,"time_next_update_utc":"Tue, 24 May 2022 00:07:41 +0000","time_eol_unix":0,"base_code":"USD","rates":{"USD":1,"AED":3.67,"AFN":90.33,"ALL":114.34,"AMD":457.39,"ANG":1.79,"AOA":416,"ARS":118.38,"AUD":1.42,"AWG":1.79,"AZN":1.7,"BAM":1.85,"BBD":2,"BDT":86.45,"BGN":1.85,"BHD":0.376,"BIF":2023.78,"BMD":1,"BND":1.38,"BOB":6.88,"BRL":4.91,"BSD":1,"BTN":77.89,"BWP":12.2,"BYN":3.14,"BZD":2,"CAD":1.28,"CDF":1993.34,"CHF":0.975,"CLP":838.63,"CNY":6.71,"COP":4048.64,"CRC":671.61,"CUP":24,"CVE":104.4,"CZK":23.33,"DJF":177.72,"DKK":7.06,"DOP":55.26,"DZD":145.88,"EGP":18.28,"ERN":15,"ETB":51.75,"EUR":0.947,"FJD":2.17,"FKP":0.801,"FOK":7.06,"GBP":0.801,"GEL":2.9,"GGP":0.801,"GHS":7.93,"GIP":0.801,"GMD":53.95,"GNF":8826.53,"GTQ":7.67,"GYD":208.68,"HKD":7.85,"HNL":24.49,"HRK":7.13,"HTG":112.23,"HUF":362.84,"IDR":14574.34,"ILS":3.37,"IMP":0.801,"INR":77.89,"IQD":1456.04,"IRR":42050.54,"ISK":131.44,"JEP":0.801,"JMD":154.82,"JOD":0.709,"JPY":128.09,"KES":116.62,"KGS":82.36,"KHR":4048.87,"KID":1.42,"KMF":465.78,"KRW":1271.59,"KWD":0.3,"KYD":0.833,"KZT":426.57,"LAK":14671.97,"LBP":1507.5,"LKR":353.42,"LRD":153.3,"LSL":15.84,"LYD":4.82,"MAD":9.9,"MDL":19.07,"MGA":3997.2,"MKD":58.34,"MMK":1835.97,"MNT":3125.54,"MOP":8.09,"MRU":36.35,"MUR":42.38,"MVR":15.41,"MWK":818.71,"MXN":19.87,"MYR":4.37,"MZN":64.26,"NAD":15.84,"NGN":415.33,"NIO":35.83,"NOK":9.74,"NPR":124.62,"NZD":1.56,"OMR":0.384,"PAB":1,"PEN":3.74,"PGK":3.52,"PHP":52.18,"PKR":200.23,"PLN":4.37,"PYG":6896.27,"QAR":3.64,"RON":4.67,"RSD":111.16,"RUB":60.69,"RWF":1050.86,"SAR":3.75,"SBD":7.95,"SCR":13.31,"SDG":451.35,"SEK":9.95,"SGD":1.38,"SHP":0.801,"SLL":12904.29,"SOS":577.05,"SRD":20.92,"SSP":440.26,"STN":23.2,"SYP":2508.7,"SZL":15.84,"THB":34.52,"TJS":12.49,"TMT":3.5,"TND":2.99,"TOP":2.32,"TRY":15.94,"TTD":6.78,"TVD":1.42,"TWD":29.58,"TZS":2323.18,"UAH":29.58,"UGX":3649.71,"UYU":40.58,"UZS":11137.78,"VES":4.87,"VND":23169.64,"VUV":116.48,"WST":2.66,"XAF":621.04,"XCD":2.7,"XDR":0.744,"XOF":621.04,"XPF":112.98,"YER":250.45,"ZAR":15.84,"ZMW":17.07,"ZWL":242.07}}

# %%
# Parse the json data
parse_json=json.loads(data)
parse_json
# Out:
# {'result': 'success',
#  'provider': 'https://www.exchangerate-api.com',
#  'documentation': 'https://www.exchangerate-api.com/docs/free',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1653264151,
#  'time_last_update_utc': 'Mon, 23 May 2022 00:02:31 +0000',
#  'time_next_update_unix': 1653350861,
#  'time_next_update_utc': 'Tue, 24 May 2022 00:07:41 +0000',
#  'time_eol_unix': 0,
#  'base_code': 'USD',
#  'rates': {'USD': 1,
#   'AED': 3.67,
#   'AFN': 90.33,
#   'ALL': 114.34,
#   'AMD': 457.39,
#   'ANG': 1.79,
#   'AOA': 416,
#   'ARS': 118.38,
#   'AUD': 1.42,
#   'AWG': 1.79,
#   'AZN': 1.7,
#   'BAM': 1.85,
#   'BBD': 2,
#   'BDT': 86.45,
#   'BGN': 1.85,
#   'BHD': 0.376,
#   'BIF': 2023.78,
#   'BMD': 1,
#   'BND': 1.38,
#   'BOB': 6.88,
#   'BRL': 4.91,
#   'BSD': 1,
#   'BTN': 77.89,
#   'BWP': 12.2,
#   'BYN': 3.14,
#   'BZD': 2,
#   'CAD': 1.28,
#   'CDF': 1993.34,
#   'CHF': 0.975,
#   'CLP': 838.63,
#   'CNY': 6.71,
#   'COP': 4048.64,
#   'CRC': 671.61,
#   'CUP': 24,
#   'CVE': 104.4,
#   'CZK': 23.33,
#   'DJF': 177.72,
#   'DKK': 7.06,
#   'DOP': 55.26,
#   'DZD': 145.88,
#   'EGP': 18.28,
#   'ERN': 15,
#   'ETB': 51.75,
#   'EUR': 0.947,
#   'FJD': 2.17,
#   'FKP': 0.801,
#   'FOK': 7.06,
#   'GBP': 0.801,
#   'GEL': 2.9,
#   'GGP': 0.801,
#   'GHS': 7.93,
#   'GIP': 0.801,
#   'GMD': 53.95,
#   'GNF': 8826.53,
#   'GTQ': 7.67,
#   'GYD': 208.68,
#   'HKD': 7.85,
#   'HNL': 24.49,
#   'HRK': 7.13,
#   'HTG': 112.23,
#   'HUF': 362.84,
#   'IDR': 14574.34,
#   'ILS': 3.37,
#   'IMP': 0.801,
#   'INR': 77.89,
#   'IQD': 1456.04,
#   'IRR': 42050.54,
#   'ISK': 131.44,
#   'JEP': 0.801,
#   'JMD': 154.82,
#   'JOD': 0.709,
#   'JPY': 128.09,
#   'KES': 116.62,
#   'KGS': 82.36,
#   'KHR': 4048.87,
#   'KID': 1.42,
#   'KMF': 465.78,
#   'KRW': 1271.59,
#   'KWD': 0.3,
#   'KYD': 0.833,
#   'KZT': 426.57,
#   'LAK': 14671.97,
#   'LBP': 1507.5,
#   'LKR': 353.42,
#   'LRD': 153.3,
#   'LSL': 15.84,
#   'LYD': 4.82,
#   'MAD': 9.9,
#   'MDL': 19.07,
#   'MGA': 3997.2,
#   'MKD': 58.34,
#   'MMK': 1835.97,
#   'MNT': 3125.54,
#   'MOP': 8.09,
#   'MRU': 36.35,
#   'MUR': 42.38,
#   'MVR': 15.41,
#   'MWK': 818.71,
#   'MXN': 19.87,
#   'MYR': 4.37,
#   'MZN': 64.26,
#   'NAD': 15.84,
#   'NGN': 415.33,
#   'NIO': 35.83,
#   'NOK': 9.74,
#   'NPR': 124.62,
#   'NZD': 1.56,
#   'OMR': 0.384,
#   'PAB': 1,
#   'PEN': 3.74,
#   'PGK': 3.52,
#   'PHP': 52.18,
#   'PKR': 200.23,
#   'PLN': 4.37,
#   'PYG': 6896.27,
#   'QAR': 3.64,
#   'RON': 4.67,
#   'RSD': 111.16,
#   'RUB': 60.69,
#   'RWF': 1050.86,
#   'SAR': 3.75,
#   'SBD': 7.95,
#   'SCR': 13.31,
#   'SDG': 451.35,
#   'SEK': 9.95,
#   'SGD': 1.38,
#   'SHP': 0.801,
#   'SLL': 12904.29,
#   'SOS': 577.05,
#   'SRD': 20.92,
#   'SSP': 440.26,
#   'STN': 23.2,
#   'SYP': 2508.7,
#   'SZL': 15.84,
#   'THB': 34.52,
#   'TJS': 12.49,
#   'TMT': 3.5,
#   'TND': 2.99,
#   'TOP': 2.32,
#   'TRY': 15.94,
#   'TTD': 6.78,
#   'TVD': 1.42,
#   'TWD': 29.58,
#   'TZS': 2323.18,
#   'UAH': 29.58,
#   'UGX': 3649.71,
#   'UYU': 40.58,
#   'UZS': 11137.78,
#   'VES': 4.87,
#   'VND': 23169.64,
#   'VUV': 116.48,
#   'WST': 2.66,
#   'XAF': 621.04,
#   'XCD': 2.7,
#   'XDR': 0.744,
#   'XOF': 621.04,
#   'XPF': 112.98,
#   'YER': 250.45,
#   'ZAR': 15.84,
#   'ZMW': 17.07,
#   'ZWL': 242.07}}

# %%
#  Store the rates variable from json
forexrates_json = parse_json['rates']
forexrates_json
# Out:
# {'USD': 1,
#  'AED': 3.67,
#  'AFN': 90.33,
#  'ALL': 114.34,
#  'AMD': 457.39,
#  'ANG': 1.79,
#  'AOA': 416,
#  'ARS': 118.38,
#  'AUD': 1.42,
#  'AWG': 1.79,
#  'AZN': 1.7,
#  'BAM': 1.85,
#  'BBD': 2,
#  'BDT': 86.45,
#  'BGN': 1.85,
#  'BHD': 0.376,
#  'BIF': 2023.78,
#  'BMD': 1,
#  'BND': 1.38,
#  'BOB': 6.88,
#  'BRL': 4.91,
#  'BSD': 1,
#  'BTN': 77.89,
#  'BWP': 12.2,
#  'BYN': 3.14,
#  'BZD': 2,
#  'CAD': 1.28,
#  'CDF': 1993.34,
#  'CHF': 0.975,
#  'CLP': 838.63,
#  'CNY': 6.71,
#  'COP': 4048.64,
#  'CRC': 671.61,
#  'CUP': 24,
#  'CVE': 104.4,
#  'CZK': 23.33,
#  'DJF': 177.72,
#  'DKK': 7.06,
#  'DOP': 55.26,
#  'DZD': 145.88,
#  'EGP': 18.28,
#  'ERN': 15,
#  'ETB': 51.75,
#  'EUR': 0.947,
#  'FJD': 2.17,
#  'FKP': 0.801,
#  'FOK': 7.06,
#  'GBP': 0.801,
#  'GEL': 2.9,
#  'GGP': 0.801,
#  'GHS': 7.93,
#  'GIP': 0.801,
#  'GMD': 53.95,
#  'GNF': 8826.53,
#  'GTQ': 7.67,
#  'GYD': 208.68,
#  'HKD': 7.85,
#  'HNL': 24.49,
#  'HRK': 7.13,
#  'HTG': 112.23,
#  'HUF': 362.84,
#  'IDR': 14574.34,
#  'ILS': 3.37,
#  'IMP': 0.801,
#  'INR': 77.89,
#  'IQD': 1456.04,
#  'IRR': 42050.54,
#  'ISK': 131.44,
#  'JEP': 0.801,
#  'JMD': 154.82,
#  'JOD': 0.709,
#  'JPY': 128.09,
#  'KES': 116.62,
#  'KGS': 82.36,
#  'KHR': 4048.87,
#  'KID': 1.42,
#  'KMF': 465.78,
#  'KRW': 1271.59,
#  'KWD': 0.3,
#  'KYD': 0.833,
#  'KZT': 426.57,
#  'LAK': 14671.97,
#  'LBP': 1507.5,
#  'LKR': 353.42,
#  'LRD': 153.3,
#  'LSL': 15.84,
#  'LYD': 4.82,
#  'MAD': 9.9,
#  'MDL': 19.07,
#  'MGA': 3997.2,
#  'MKD': 58.34,
#  'MMK': 1835.97,
#  'MNT': 3125.54,
#  'MOP': 8.09,
#  'MRU': 36.35,
#  'MUR': 42.38,
#  'MVR': 15.41,
#  'MWK': 818.71,
#  'MXN': 19.87,
#  'MYR': 4.37,
#  'MZN': 64.26,
#  'NAD': 15.84,
#  'NGN': 415.33,
#  'NIO': 35.83,
#  'NOK': 9.74,
#  'NPR': 124.62,
#  'NZD': 1.56,
#  'OMR': 0.384,
#  'PAB': 1,
#  'PEN': 3.74,
#  'PGK': 3.52,
#  'PHP': 52.18,
#  'PKR': 200.23,
#  'PLN': 4.37,
#  'PYG': 6896.27,
#  'QAR': 3.64,
#  'RON': 4.67,
#  'RSD': 111.16,
#  'RUB': 60.69,
#  'RWF': 1050.86,
#  'SAR': 3.75,
#  'SBD': 7.95,
#  'SCR': 13.31,
#  'SDG': 451.35,
#  'SEK': 9.95,
#  'SGD': 1.38,
#  'SHP': 0.801,
#  'SLL': 12904.29,
#  'SOS': 577.05,
#  'SRD': 20.92,
#  'SSP': 440.26,
#  'STN': 23.2,
#  'SYP': 2508.7,
#  'SZL': 15.84,
#  'THB': 34.52,
#  'TJS': 12.49,
#  'TMT': 3.5,
#  'TND': 2.99,
#  'TOP': 2.32,
#  'TRY': 15.94,
#  'TTD': 6.78,
#  'TVD': 1.42,
#  'TWD': 29.58,
#  'TZS': 2323.18,
#  'UAH': 29.58,
#  'UGX': 3649.71,
#  'UYU': 40.58,
#  'UZS': 11137.78,
#  'VES': 4.87,
#  'VND': 23169.64,
#  'VUV': 116.48,
#  'WST': 2.66,
#  'XAF': 621.04,
#  'XCD': 2.7,
#  'XDR': 0.744,
#  'XOF': 621.04,
#  'XPF': 112.98,
#  'YER': 250.45,
#  'ZAR': 15.84,
#  'ZMW': 17.07,
#  'ZWL': 242.07}

# %%
# Load the json dictionary into a dataframe
forex_latest=pd.DataFrame(forexrates_json.items(), columns=['Currency', 'ExchangeRate'])
forex_latest
# Out:
#     Currency  ExchangeRate
# 0        USD          1.00
# 1        AED          3.67
# 2        AFN         90.33
# 3        ALL        114.34
# 4        AMD        457.39
# ..       ...           ...
# 156      XPF        112.98
# 157      YER        250.45
# 158      ZAR         15.84
# 159      ZMW         17.07
# 160      ZWL        242.07
#
# [161 rows x 2 columns]

# %%
# Add a field in the dataframe to capture load date
from datetime import date
forex_latest['Date']=date.today()
forex_latest
# Out:
#     Currency  ExchangeRate        Date
# 0        USD          1.00  2022-05-22
# 1        AED          3.67  2022-05-22
# 2        AFN         90.33  2022-05-22
# 3        ALL        114.34  2022-05-22
# 4        AMD        457.39  2022-05-22
# ..       ...           ...         ...
# 156      XPF        112.98  2022-05-22
# 157      YER        250.45  2022-05-22
# 158      ZAR         15.84  2022-05-22
# 159      ZMW         17.07  2022-05-22
# 160      ZWL        242.07  2022-05-22
#
# [161 rows x 3 columns]

# %%
import os
# Change directory
os.chdir("/Users/rajponnam/Documents/ds_course/DSC_540/Week_9_10_assignments") 
os.getcwd()
# Out:
# '/Users/rajponnam/Documents/ds_course/DSC_540/Week_9_10_assignments'

# %%
# Read an excel file with Currency code and country name
countryCurrency=pd.read_excel("list_of_currency_in_world.xlsx")
countryCurrency
# Out:
#                CountryName           CurrencyName CurrencyCodeA  CurrencyCodeN
# 0              AFGHANISTAN                Afghani           AFN          971.0
# 1                  ALBANIA                    Lek           ALL            8.0
# 2                  ALGERIA         Algerian Dinar           DZD           12.0
# 3           AMERICAN SAMOA              US Dollar           USD          840.0
# 4                  ANDORRA                   Euro           EUR          978.0
# ..                     ...                    ...           ...            ...
# 435               ZIMBABWE  Zimbabwe Dollar (new)           ZWN          942.0
# 436               ZIMBABWE        Zimbabwe Dollar           ZWR          935.0
# 437        ZZ01_Gold-Franc             Gold-Franc           XFO            NaN
# 438  ZZ02_RINET Funds Code       RINET Funds Code           XRE            NaN
# 439         ZZ05_UIC-Franc              UIC-Franc           XFU            NaN
#
# [440 rows x 4 columns]

# %%
# Join the two dataframes
forex = pd.merge(forex_latest, countryCurrency, how='inner', left_on = 'Currency', right_on = 'CurrencyCodeA')
forex= forex[['Currency', 'ExchangeRate','CountryName','CurrencyName']]
forex
# Out:
#     Currency  ExchangeRate                           CountryName  \
# 0        USD          1.00                        AMERICAN SAMOA
# 1        USD          1.00      BONAIRE, SINT EUSTATIUS AND SABA
# 2        USD          1.00  BRITISH INDIAN OCEAN TERRITORY (THE)
# 3        USD          1.00                               ECUADOR
# 4        USD          1.00                           EL SALVADOR
# ..       ...           ...                                   ...
# 256      ZAR         15.84                               LESOTHO
# 257      ZAR         15.84                               NAMIBIA
# 258      ZAR         15.84                          SOUTH AFRICA
# 259      ZMW         17.07                                ZAMBIA
# 260      ZWL        242.07                              ZIMBABWE
#
#         CurrencyName
# 0          US Dollar
# 1          US Dollar
# 2          US Dollar
# 3          US Dollar
# 4          US Dollar
# ..               ...
# 256             Rand
# 257             Rand
# 258             Rand
# 259   Zambian Kwacha
# 260  Zimbabwe Dollar
#
# [261 rows x 4 columns]

# %%
# Transform the country name and currency name data into upper case
forex.CountryName = forex['CountryName'].str.upper()
forex.CurrencyName = forex['CurrencyName'].str.upper()
forex
# Out:
#     Currency  ExchangeRate                           CountryName  \
# 0        USD          1.00                        AMERICAN SAMOA
# 1        USD          1.00      BONAIRE, SINT EUSTATIUS AND SABA
# 2        USD          1.00  BRITISH INDIAN OCEAN TERRITORY (THE)
# 3        USD          1.00                               ECUADOR
# 4        USD          1.00                           EL SALVADOR
# ..       ...           ...                                   ...
# 256      ZAR         15.84                               LESOTHO
# 257      ZAR         15.84                               NAMIBIA
# 258      ZAR         15.84                          SOUTH AFRICA
# 259      ZMW         17.07                                ZAMBIA
# 260      ZWL        242.07                              ZIMBABWE
#
#         CurrencyName
# 0          US DOLLAR
# 1          US DOLLAR
# 2          US DOLLAR
# 3          US DOLLAR
# 4          US DOLLAR
# ..               ...
# 256             RAND
# 257             RAND
# 258             RAND
# 259   ZAMBIAN KWACHA
# 260  ZIMBABWE DOLLAR
#
# [261 rows x 4 columns]

# %%
# Remove duplicates in the dataframe
forex = forex.drop_duplicates()
forex
# Out:
#     Currency  ExchangeRate                           CountryName  \
# 0        USD          1.00                        AMERICAN SAMOA
# 1        USD          1.00      BONAIRE, SINT EUSTATIUS AND SABA
# 2        USD          1.00  BRITISH INDIAN OCEAN TERRITORY (THE)
# 3        USD          1.00                               ECUADOR
# 4        USD          1.00                           EL SALVADOR
# ..       ...           ...                                   ...
# 256      ZAR         15.84                               LESOTHO
# 257      ZAR         15.84                               NAMIBIA
# 258      ZAR         15.84                          SOUTH AFRICA
# 259      ZMW         17.07                                ZAMBIA
# 260      ZWL        242.07                              ZIMBABWE
#
#         CurrencyName
# 0          US DOLLAR
# 1          US DOLLAR
# 2          US DOLLAR
# 3          US DOLLAR
# 4          US DOLLAR
# ..               ...
# 256             RAND
# 257             RAND
# 258             RAND
# 259   ZAMBIAN KWACHA
# 260  ZIMBABWE DOLLAR
#
# [261 rows x 4 columns]

# %%
# Identify number of countries using the same currency
currency_distro = forex.groupby(["Currency"]).count().reset_index()

# %%
# Rename the column names
currency_distro= currency_distro[['Currency', 'ExchangeRate']]
currency_distro.columns =['Currency', 'NumberOfCountries']
currency_distro
# Out:
#     Currency  NumberOfCountries
# 0        AED                  1
# 1        AFN                  1
# 2        ALL                  1
# 3        AMD                  1
# 4        ANG                  3
# ..       ...                ...
# 150      XPF                  3
# 151      YER                  1
# 152      ZAR                  3
# 153      ZMW                  1
# 154      ZWL                  1
#
# [155 rows x 2 columns]

# %%
# Currencies used in more than one country
currency_distro = currency_distro[currency_distro["NumberOfCountries"]>1]
currency_distro
# Out:
#     Currency  NumberOfCountries
# 4        ANG                  3
# 7        AUD                  8
# 27       CHF                  2
# 36       DKK                  3
# 42       EUR                 35
# 45       GBP                  4
# 55       HRK                  2
# 58       IDR                  2
# 60       INR                  2
# 81       MAD                  2
# 91       MWK                  2
# 98       NOK                  3
# 100      NZD                  5
# 103      PEN                  2
# 110      RON                  2
# 117      SDG                  2
# 127      SZL                  2
# 133      TRY                  2
# 139      USD                 19
# 146      XAF                  6
# 147      XCD                  8
# 149      XOF                  8
# 150      XPF                  3
# 152      ZAR                  3

# %%
# Plot the forex rates using pyplot

import matplotlib.pyplot as plt

plt.barh(currency_distro.Currency, currency_distro.NumberOfCountries, color='green')
plt.xlabel("Currency")
plt.ylabel("Number of Countries with the currency")
plt.title("Currency used in more than one country")

plt.show()
